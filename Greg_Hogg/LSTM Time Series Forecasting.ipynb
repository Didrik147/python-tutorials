# %% [markdown]
# # LSTM Time Series Forecasting Tutorial in Python
#
# Made by using the following tutorial by Greg Hogg: https://www.youtube.com/watch?v=c0k-YLQGKjY

# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %% [markdown]
# Information about the dataset: https://www.kaggle.com/datasets/mnassrib/jena-climate

# %%
df = pd.read_csv('jena_climate_2009_2016.csv')
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 0        93.30          3.33          3.11          0.22       1.94
# 1        93.40          3.23          3.02          0.21       1.89
# 2        93.90          3.21          3.01          0.20       1.88
# 3        94.20          3.26          3.07          0.19       1.92
# 4        94.10          3.27          3.08          0.19       1.92
# ...        ...           ...           ...           ...        ...
# 420546   73.10          4.52          3.30          1.22       2.06
# 420547   69.71          4.77          3.32          1.44       2.07
# 420548   67.91          4.84          3.28          1.55       2.05
# 420549   71.80          4.46          3.20          1.26       1.99
# 420550   75.70          4.27          3.23          1.04       2.01
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0                  3.12       1307.75      1.03           1.75     152.3
# 1                  3.03       1309.80      0.72           1.50     136.1
# 2                  3.02       1310.24      0.19           0.63     171.6
# 3                  3.08       1309.19      0.34           0.50     198.0
# 4                  3.09       1309.00      0.32           0.63     214.3
# ...                 ...           ...       ...            ...       ...
# 420546             3.30       1292.98      0.67           1.52     240.0
# 420547             3.32       1289.44      1.14           1.92     234.3
# 420548             3.28       1288.39      1.08           2.00     215.2
# 420549             3.20       1293.56      1.49           2.16     225.8
# 420550             3.23       1296.38      1.23           1.96     184.9
#
# [420551 rows x 15 columns]

# %%
df = df[5::6]
df.head()
# Out:
#               Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# 5   01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78    94.4
# 11  01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77    93.2
# 17  01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66    93.5
# 23  01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02    92.6
# 29  01.01.2009 05:00:00    997.46     -9.63    263.72       -10.65    92.2
#
#     VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  \
# 5           3.33          3.14          0.19       1.96             3.15
# 11          3.12          2.90          0.21       1.81             2.91
# 17          3.13          2.93          0.20       1.83             2.94
# 23          3.07          2.85          0.23       1.78             2.85
# 29          2.94          2.71          0.23       1.69             2.71
#
#     rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 5        1307.86      0.21           0.63     192.7
# 11       1312.25      0.25           0.63     190.3
# 17       1312.18      0.18           0.63     167.2
# 23       1313.61      0.10           0.38     240.0
# 29       1317.19      0.40           0.88     157.0

# %%
df.index = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S')

# %%
df
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 01:00:00  01.01.2009 01:00:00    996.50     -8.05    265.38
# 2009-01-01 02:00:00  01.01.2009 02:00:00    996.62     -8.88    264.54
# 2009-01-01 03:00:00  01.01.2009 03:00:00    996.84     -8.81    264.59
# 2009-01-01 04:00:00  01.01.2009 04:00:00    996.99     -9.05    264.34
# 2009-01-01 05:00:00  01.01.2009 05:00:00    997.46     -9.63    263.72
# ...                                  ...       ...       ...       ...
# 2016-12-31 19:10:00  31.12.2016 19:10:00   1002.18     -0.98    272.01
# 2016-12-31 20:10:00  31.12.2016 20:10:00   1001.40     -1.40    271.66
# 2016-12-31 21:10:00  31.12.2016 21:10:00   1001.19     -2.75    270.32
# 2016-12-31 22:10:00  31.12.2016 22:10:00   1000.65     -2.89    270.22
# 2016-12-31 23:10:00  31.12.2016 23:10:00   1000.11     -3.93    269.23
#
#                      Tdew (degC)  rh (%)  VPmax (mbar)  VPact (mbar)  \
# Date Time
# 2009-01-01 01:00:00        -8.78   94.40          3.33          3.14
# 2009-01-01 02:00:00        -9.77   93.20          3.12          2.90
# 2009-01-01 03:00:00        -9.66   93.50          3.13          2.93
# 2009-01-01 04:00:00       -10.02   92.60          3.07          2.85
# 2009-01-01 05:00:00       -10.65   92.20          2.94          2.71
# ...                          ...     ...           ...           ...
# 2016-12-31 19:10:00        -5.36   72.00          5.69          4.09
# 2016-12-31 20:10:00        -6.84   66.29          5.51          3.65
# 2016-12-31 21:10:00        -6.90   72.90          4.99          3.64
# 2016-12-31 22:10:00        -7.15   72.30          4.93          3.57
# 2016-12-31 23:10:00        -8.09   72.60          4.56          3.31
#
#                      VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# Date Time
# 2009-01-01 01:00:00          0.19       1.96             3.15       1307.86
# 2009-01-01 02:00:00          0.21       1.81             2.91       1312.25
# 2009-01-01 03:00:00          0.20       1.83             2.94       1312.18
# 2009-01-01 04:00:00          0.23       1.78             2.85       1313.61
# 2009-01-01 05:00:00          0.23       1.69             2.71       1317.19
# ...                           ...        ...              ...           ...
# 2016-12-31 19:10:00          1.59       2.54             4.08       1280.70
# 2016-12-31 20:10:00          1.86       2.27             3.65       1281.87
# 2016-12-31 21:10:00          1.35       2.26             3.63       1288.02
# 2016-12-31 22:10:00          1.37       2.22             3.57       1288.03
# 2016-12-31 23:10:00          1.25       2.06             3.31       1292.41
#
#                      wv (m/s)  max. wv (m/s)  wd (deg)
# Date Time
# 2009-01-01 01:00:00      0.21           0.63     192.7
# 2009-01-01 02:00:00      0.25           0.63     190.3
# 2009-01-01 03:00:00      0.18           0.63     167.2
# 2009-01-01 04:00:00      0.10           0.38     240.0
# 2009-01-01 05:00:00      0.40           0.88     157.0
# ...                       ...            ...       ...
# 2016-12-31 19:10:00      0.87           1.36     190.6
# 2016-12-31 20:10:00      1.02           1.92     225.4
# 2016-12-31 21:10:00      0.71           1.56     158.7
# 2016-12-31 22:10:00      0.35           0.68     216.7
# 2016-12-31 23:10:00      0.56           1.00     202.6
#
# [70091 rows x 15 columns]

# %%
temp = df['T (degC)']
temp.plot()
# Out:
# <Axes: xlabel='Date Time'>

# %%
# [[1,2,3,4,5]] [6]
# [[2,3,4,5,6]] [7]
# [[3,4,5,6,7]] [8]

# This is a 3D tensor

# [[[1], [2], [3], [4], [5]]] [6]
# [[[2], [3], [4], [5], [6]]] [7]
# [[[3], [4], [5], [6], [7]]] [8]

def df_to_X_y(df, window_size=5):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np) - window_size):
    row = [[a] for a in df_as_np[i:i+5]]
    X.append(row)
    label = df_as_np[i+5]
    y.append(label)
  
  return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X, y = df_to_X_y(temp, WINDOW_SIZE)
X.shape, y.shape
# Out:
# ((70086, 5, 1), (70086,))

# %%
X_train, y_train = X[:60_000], y[:60_000]
X_val, y_val = X[60_000:65_000], y[60_000:65_000]
X_test, y_test = X[65_000:], y[65_000:]

X_train.shape, y_train.shape, X_val.shape, y_val.shape, X_test.shape, y_test.shape,
# Out:
# ((60000, 5, 1), (60000,), (5000, 5, 1), (5000,), (5086, 5, 1), (5086,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

# %%
model1 = Sequential()
model1.add(InputLayer((5, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │           520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,425 (68.07 KB)
#  Trainable params: 17,425 (68.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp = ModelCheckpoint('model1.keras', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=10, callbacks=[cp])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 57.3024 - root_mean_squared_error: 7.2704 - val_loss: 1.2059 - val_root_mean_squared_error: 1.0982
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 2.1528 - root_mean_squared_error: 1.4654 - val_loss: 0.6571 - val_root_mean_squared_error: 0.8106
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.0164 - root_mean_squared_error: 1.0079 - val_loss: 0.5456 - val_root_mean_squared_error: 0.7387
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - loss: 0.7561 - root_mean_squared_error: 0.8695 - val_loss: 0.5226 - val_root_mean_squared_error: 0.7229
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.7000 - root_mean_squared_error: 0.8365 - val_loss: 0.5047 - val_root_mean_squared_error: 0.7104
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.6689 - root_mean_squared_error: 0.8178 - val_loss: 0.4957 - val_root_mean_squared_error: 0.7041
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.6628 - root_mean_squared_error: 0.8141 - val_loss: 0.5012 - val_root_mean_squared_error: 0.7079
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.6587 - root_mean_squared_error: 0.8115 - val_loss: 0.4965 - val_root_mean_squared_error: 0.7046
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.6601 - root_mean_squared_error: 0.8122 - val_loss: 0.4910 - val_root_mean_squared_error: 0.7007
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.6505 - root_mean_squared_error: 0.8065 - val_loss: 0.4884 - val_root_mean_squared_error: 0.6989

# %%
from tensorflow.keras.models import load_model

model1 = load_model('model1.keras')

# %%
train_predictions = model1.predict(X_train).flatten()
train_results = pd.DataFrame(data={
  'Train Predictions' : train_predictions,
  'Actuals' : y_train
  })

train_results
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step
#        Train Predictions  Actuals
# 0             -10.030196    -9.67
# 1              -9.905936    -9.17
# 2              -9.027481    -8.10
# 3              -7.498440    -7.66
# 4              -7.391639    -7.04
# ...                  ...      ...
# 59995           5.976116     6.07
# 59996           7.225130     9.88
# 59997          12.158375    13.53
# 59998          15.976671    15.43
# 59999          16.520014    15.54
#
# [60000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(train_results['Train Predictions'][50:100])
plt.plot(train_results['Actuals'][50:100])

# %%
val_predictions = model1.predict(X_val).flatten()
val_results = pd.DataFrame(data={'Val Predictions':val_predictions, 'Actuals':y_val})
val_results
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
#       Val Predictions  Actuals
# 0           15.439943    14.02
# 1           13.193199    13.67
# 2           13.032957    12.27
# 3           11.477614    11.19
# 4           10.352081    10.85
# ...               ...      ...
# 4995        17.382917    18.27
# 4996        17.359152    17.85
# 4997        17.157732    16.65
# 4998        15.848193    15.85
# 4999        15.065751    15.09
#
# [5000 rows x 2 columns]

# %%
plt.plot(val_results['Val Predictions'][:100])
plt.plot(val_results['Actuals'][:100])

# %%
test_predictions = model1.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test})
test_results
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#       Test Predictions  Actuals
# 0            14.375336    13.99
# 1            13.230690    13.46
# 2            12.824664    12.93
# 3            12.417165    12.43
# 4            11.979308    12.17
# ...                ...      ...
# 5081         -1.171487    -0.98
# 5082         -1.598463    -1.40
# 5083         -1.759679    -2.75
# 5084         -3.318223    -2.89
# 5085         -3.300655    -3.93
#
# [5086 rows x 2 columns]

# %%
plt.plot(test_results['Test Predictions'][:100])
plt.plot(test_results['Actuals'][:100])
